# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
s2_a = 0
s2_b = 1
s2_c = 4  
s2_d = 7
s2_e = 5
s2_f = 0


hasil_a = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("soal 1")
print("hasil dari tamat s2 adalah " + str(hasil_a))
print("")
s1_a = 4
s1_b = 12
s1_c= 6 
s1_d = 13
s1_e = 14
s1_f = 0

hasil_b = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("tamat s1")
print("hasil dari tamat s1 adalah " + str(hasil_b))
print("")

print("===tamat sma==")
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75

hasil_c= sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("hasil dari tamat sma adalah " + str(hasil_c))
print("")

print("==tamat smp==")
smp_a = 5
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
hasil_d = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("hasil dari tamat sma adalah " + str(hasil_d))
print("")

print("==tamat sd==")
sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1
hasil_e = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f
print("hasil dari tamat sd adalah " + str(hasil_e))
print("")

print("==tidak diketahui==")
td_a = 2 
td_b = 14
td_c = 3
td_d = 10
td_e = 0
td_f = 1
hasil_f = td_a + td_b + td_c + td_d + td_e + td_f
print("hasil dari tamat tidak diketahui adalah " + str(hasil_f))
print("")

a = 0.0
b = 0.8
c = 1.7999999999999998
d = 0.5
e = 0.5
f = 0.6
hasil = (a + b) + (c + d) + (e + f)
print("Hasil dari Usia >70 Adalah " + str(hasil))
print("")
print("")

a = 1
b = 0.25
hasil = (a * b)
print("Hasil dari tamat S2 Adalah " + str(hasil))
a = 12
b = 0.20
hasil = (a * b)
print("Hasil dari tamat S1 Adalah " + str(hasil))
a = 17
b = 0.15
hasil = (a * b)
print("Hasil dari tamat SMA Adalah " + str(hasil))
a = 6
b = 0.10
hasil = (a * b)
print("Hasil dari tamat SMP Adalah " + str(hasil))
a = 8
b = 0.5
hasil = (a * b)
print("Hasil dari tamat SD Adalah " + str(hasil))
a = 14
b = 0.3
hasil = (a * b)
print("Hasil dari tamat Tidak Diketahui Adalah " + str(hasil))
print()

print("soal 3")
a_index = 0.25
b_index = 0.20
c_index = 0.15
d_index = 0.10
e_index = 0.05
f_index = 0.03

s2  = 0  * a_index
s1 = 4 * b_index
sma = 12 * c_index
smp = 5 * d_index
sd = 1 * e_index
td = 2 * f_index

s2  = 1 * a_index
s1 = 12 * b_index
sma = 17 * c_index
smp = 6 * d_index
sd = 8 * e_index
td = 14 * f_index

s2  = 4 * a_index
s1 = 6 * b_index
sma = 5 * c_index
smp = 15 * d_index
sd = 0* e_index
td = 3 * f_index

s2  = 7 * a_index
s1 = 13 * b_index
sma = 20 * c_index
smp = 9 * d_index
sd = 19* e_index
td = 10* f_index

s2  = 5 * a_index
s1 = 14 * b_index
sma = 11 * c_index
smp = 20 * d_index
sd = 10* e_index
td = 0 * f_index

s2  = 0 * a_index
s1 = 0* b_index
sma = 75 * c_index
smp = 15 * d_index
sd = 1 * e_index
td = 1 * f_index



print("usia 70")
print("maka hasil bobot " + str(s2_a))
print("maka hasil bobot " + str(s1_a))
print("maka hasil bobot " + str(sma_a))
print("maka hasil bobot " + str(smp_a))
print("maka hasil bobot " + str(sd_a))
print("maka hasil bobot " + str(td_a))

print("usia 60")
print("maka hasil bobot " + str(s2_b))
print("maka hasil bobot " + str(s1_b))
print("maka hasil bobot " + str(sma_b))
print("maka hasil bobot " + str(smp_b))
print("maka hasil bobot " + str(sd_b))
print("maka hasil bobot " + str(td_b))

print("usia 50")
print("maka hasil bobot " + str(s2_c))
print("maka hasil bobot " + str(s1_c))
print("maka hasil bobot " + str(sma_c))
print("maka hasil bobot " + str(smp_c))
print("maka hasil bobot " + str(sd_c))
print("maka hasil bobot " + str(td_c))

print("usia 40")
print("maka hasil bobot " + str(s2_d))
print("maka hasil bobot " + str(s1_d))
print("maka hasil bobot " + str(sma_d))
print("maka hasil bobot " + str(smp_d))
print("maka hasil bobot " + str(sd_d))
print("maka hasil bobot " + str(td_d))

print("usia 30")
print("maka hasil bobot " + str(s2_e))
print("maka hasil bobot " + str(s1_e))
print("maka hasil bobot " + str(sma_e))
print("maka hasil bobot " + str(smp_e))
print("maka hasil bobot " + str(sd_e))
print("maka hasil bobot " + str(td_e))

print("usia 20")
print("maka hasil bobot " + str(s2_f))
print("maka hasil bobot " + str(s1_f))
print("maka hasil bobot " + str(sma_f))
print("maka hasil bobot " + str(smp_f))
print("maka hasil bobot " + str(sd_f))
print("maka hasil bobot " + str(td_f))
print()
# Out:
# soal 1
# hasil dari tamat s2 adalah 17
#
# tamat s1
# hasil dari tamat s1 adalah 49
#
# ===tamat sma==
# hasil dari tamat sma adalah 140
#
# ==tamat smp==
# hasil dari tamat sma adalah 70
#
# ==tamat sd==
# hasil dari tamat sd adalah 39
#
# ==tidak diketahui==
# hasil dari tamat tidak diketahui adalah 30
#
# Hasil dari Usia >70 Adalah 4.199999999999999
#
#
# Hasil dari tamat S2 Adalah 0.25
# Hasil dari tamat S1 Adalah 2.4000000000000004
# Hasil dari tamat SMA Adalah 2.55
# Hasil dari tamat SMP Adalah 0.6000000000000001
# Hasil dari tamat SD Adalah 4.0
# Hasil dari tamat Tidak Diketahui Adalah 4.2
#
# soal 3
# usia 70
# maka hasil bobot 0
# maka hasil bobot 4
# maka hasil bobot 12
# maka hasil bobot 5
# maka hasil bobot 1
# maka hasil bobot 2
# usia 60
# maka hasil bobot 1
# maka hasil bobot 12
# maka hasil bobot 17
# maka hasil bobot 6
# maka hasil bobot 8
# maka hasil bobot 14
# usia 50
# maka hasil bobot 4
# maka hasil bobot 6
# maka hasil bobot 5
# maka hasil bobot 15
# ...

# %%
print("=====soal 4====")
terkecil = {"usia 70 : 24"}
print ("maka bobot terkecil adalah :" + str(terkecil))
print("")
# Out:
# =====soal 4====
# maka bobot terkecil adalah :{'usia 70 : 24'}

# %%
print("====tugas 5====")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["s2", "s2", " sma",'smp','sd','tidak diketahui']
pajak = [17, 149, 70.,70,38,30]
c = ['red','green','blue','red','green','blue']   
ax.pie(pajak, labels=perusahaan,autopct='%1.2f%%')
plt.title("maka setahun perusahan ")
plt.show() 

print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ["s2", "s2", " sma",'smp','sd','tidak diketahui']
pajak = [17, 149, 70.,70,38,30]
c = ['red','green','blue','red','green','blue','black']
plt.title("maka setahun perusahan")
ax.bar(perusahaan, pajak, color = c)            
plt.show()
# Out:
# ====tugas 5====
