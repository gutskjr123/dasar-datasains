# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
burger = 24000
pizza = 52000
dimsun =30000
ekkado =7500
milkshake = 10000
eskrim = 15000

print("====belanjaan ahmad ===")
burger1 = 6
pizza1 = 3
dimsun1 = 4
ekkado1 = 4
milkshake1 =2
eskrim1 = 5
js =(burger1 * burger)+(pizza1 * pizza)+(dimsun1 * dimsun)+(ekkado1 * ekkado)+(milkshake1 * milkshake)+(eskrim1 * eskrim)
jm = (burger1 + pizza1 + dimsun1 + ekkado1 + milkshake1 + eskrim1)
print("maka semua jumlah makanan yang di pesan adalah : " + str(js))
print("maka jumlah belanjaan "  + str(jm))
# Out:
# ====belanjaan ahmad ===
# maka semua jumlah makanan yang di pesan adalah : 545000
# maka jumlah belanjaan 24

# %%
print ("===sol 2 =======")
f1 = ( burger1 / jm )
f2 = ( pizza1 / jm )
f3 = ( dimsun1 / jm )
f4 =  ( ekkado1 / jm )
f5 = ( milkshake1 / jm )
f6 = ( eskrim1 / jm )

print("burger1 " +str(f1))
print("pizza1 " +str(f2))
print("dimsun1 " +str(f3))
print("ekkado1 " +str(f4))
print("milkshake1 " +str(f5))
print("eskrim1 " +str(f6))
print("")

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jumlah = ("JUMLAH BELANJAAN")
jurusan = ["burger","pizza","dimsun","ekkado","milkshake","eskrim"]
siswa = [0.25,  0.125,  0.16666666666666666, 0.16666666666666666,  0.08333333333333333, 0.20833333333333334]
ax.pie(siswa,labels=jurusan,autopct="%1.2f%%")
plt.show("")

print()
# Out:
# ===sol 2 =======
# burger1 0.25
# pizza1 0.125
# dimsun1 0.16666666666666666
# ekkado1 0.16666666666666666
# milkshake1 0.08333333333333333
# eskrim1 0.20833333333333334

# %%
print("=====burger=====")
print()
ba = 4
pa = 2
j1 = 7.5
uang_a = 200000
jml_a =(0.70 * (ba * 24000) + (pa * 52000))) + (7.5 * 2000) - 5000 disc  = uang_a jm_a)
jml_a = uang_a -jml_a

# %%
(print ('===soal 4 =====')
burger = 4
pizza = 2
 jml_a (0.30 * ((burger * 24000) + (pizza * 52000))) + 5000
 print(maka jumlah potongan ahmad adalah  :rp. + str(jml_a)
 
 dimsun = 3
 eskrim = 1
